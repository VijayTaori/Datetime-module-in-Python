# %% [markdown]
# <a href="https://colab.research.google.com/github/VijayTaori/Datetime-module-in-Python/blob/master/convert_unix_timestamp2DateTime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
df_open = pd.read_csv('/content/crypto_et_open_ut.csv')

# %%
print(df_open.columns)
df_open.dtypes
# Out:
# Index(['Open_Position ID', 'Open Datetime', 'Open Date_x', 'Open Action',
#        'Open Units', 'Open Amount_Eur', 'Open Rate_Eur',
#        'open_unix_timestamp'],
#       dtype='object')
# Open_Position ID         int64
# Open Datetime           object
# Open Date_x             object
# Open Action             object
# Open Units             float64
# Open Amount_Eur        float64
# Open Rate_Eur          float64
# open_unix_timestamp      int64
# dtype: object

# %%
df_open
# Out:
#      Open_Position ID     Open Datetime       Open Date_x  \
# 0           599295474  17/04/2020 13:09  17/04/2020 00:00
# 1           599875563  17/04/2020 16:40  17/04/2020 00:00
# 2           599996081  17/04/2020 18:42  17/04/2020 00:00
# 3           600052383  18/04/2020 13:49  18/04/2020 00:00
# 4           600057583  18/04/2020 16:48  18/04/2020 00:00
# ..                ...               ...               ...
# 805        1395459836  17/11/2021 10:55  17/11/2021 00:00
# 806        1395474358  17/11/2021 11:33  17/11/2021 00:00
# 807        1419921913  04/12/2021 05:26  04/12/2021 00:00
# 808        1425416509  09/12/2021 09:14  09/12/2021 00:00
# 809        2325392242  16/11/2022 16:35  16/11/2022 00:00
#
#                  Open Action  Open Units  Open Amount_Eur  Open Rate_Eur  \
# 0                Buy Bitcoin    0.014029        92.484010    6592.389676
# 1               Buy Ethereum    0.580499        92.484010     159.322203
# ...

# %%
# If open_unix_timestamp was not in int64 then convert it using below codeline
#df_open['open_unix_timestamp'] = pd.to_numeric(df_open['open_unix_timestamp'])

# %%
# dayfirst=True not required as this is absolute conversion
df_open['open_unix_timestamp'] = pd.to_datetime(df_open['open_unix_timestamp'],
                                                dayfirst=True,unit='s')

# %%
df_open.dtypes
# Out:
# Open_Position ID                int64
# Open Datetime                  object
# Open Date_x                    object
# Open Action                    object
# Open Units                    float64
# Open Amount_Eur               float64
# Open Rate_Eur                 float64
# open_unix_timestamp    datetime64[ns]
# dtype: object

# %%
df_open
# Out:
#      Open_Position ID     Open Datetime       Open Date_x  \
# 0           599295474  17/04/2020 13:09  17/04/2020 00:00
# 1           599875563  17/04/2020 16:40  17/04/2020 00:00
# 2           599996081  17/04/2020 18:42  17/04/2020 00:00
# 3           600052383  18/04/2020 13:49  18/04/2020 00:00
# 4           600057583  18/04/2020 16:48  18/04/2020 00:00
# ..                ...               ...               ...
# 805        1395459836  17/11/2021 10:55  17/11/2021 00:00
# 806        1395474358  17/11/2021 11:33  17/11/2021 00:00
# 807        1419921913  04/12/2021 05:26  04/12/2021 00:00
# 808        1425416509  09/12/2021 09:14  09/12/2021 00:00
# 809        2325392242  16/11/2022 16:35  16/11/2022 00:00
#
#                  Open Action  Open Units  Open Amount_Eur  Open Rate_Eur  \
# 0                Buy Bitcoin    0.014029        92.484010    6592.389676
# 1               Buy Ethereum    0.580499        92.484010     159.322203
# ...
